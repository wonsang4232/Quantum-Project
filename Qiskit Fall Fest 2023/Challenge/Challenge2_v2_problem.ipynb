# %% [markdown]
# # Qiskit Fall Fest at Korea University 2023
#
# ![QFF Logo](images/QFF-logo.png)
#
# ## Challenge 2: Quiz

# %% [markdown]
# Challenge 2에서는 여러분이 워크숍에서 배웠던 지식들을 점검해보는 퀴즈들이 있습니다.

# %% [markdown]
# * * *

# %% [markdown]
# ## Quiz 설명
#
# Quiz를 보실 준비가 되셨나요?
#
# 각 문제에서 주어진 선지 중에서 답을 고르셔야 합니다. 각 문제에서 정답은 단 한 개 입니다. 객관식 문제의 경우 정답은 반드시 **list with an integer(정수를 원소로 갖는 리스트 자료형)** 으로 작성되어야 하고 리스트 안에는 선택한 답의 번호를 고르시면 됩니다. 만약 잘 몰라서 문제를 넘어가고 싶으신 경우 빈 리스트를 제출하시면 됩니다.
#
# 코딩 문제의 경우 주석 안의 지시에 따라 적절하게 코딩하시길 바랍니다.
#
# ### 점수
#
# 최대 획득 가능 점수는 미공개입니다!

# %% [markdown]
# <a id="badge1_ex1"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 1: The Initial state is $|0⟩$. The goal is to reach the state $|1⟩$. Which gate do you apply? </b>
#
# Choose the correct answer from the following list. There is only one correct answer.
#
# 1. H gate
# 2. Z gate
# 3. X gate
# 4. S gate
#
# The answer must be a **list with an integer** denoting the option number. If you think all options are wrong, you can just pass an empty list.
#
# </div>

# %%
answer1 = [3] # build your code here

# %% [markdown]
# <a id="badge1_ex3"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 2: We would like to create superposition. The goal is to reach the state $|+\rangle = \frac{1}{\sqrt{2}}(|0\rangle  + |1\rangle )$ .   Which gate do you apply?  </b>
#
# 1. X gate
# 2. Y gate
# 3. Z gate
# 4. H gate
#
#
# </div>

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %%
answer2 = [4] # build your code here

# %% [markdown]
# <a id = "badge1_ex4"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 3: When two quantum particles are correlated such that a measurement on one immediately affects the other, it is called:  </b>
#
# 1. Quantum Gates
# 2. Quantum Entanglement
# 3. Quantum Superposition
# 4. Quantum Teleportation
#
#
# </div>

# %%
answer3 = [2] # build your code here

# %% [markdown]
# <a id = "badge1_ex5"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 4: The goal is to reach the state $|-\rangle = \frac{1}{\sqrt{2}}(|0\rangle - |1\rangle)$.  Which gate sequence do you apply? </b>
#
# 1. X gate -> Z gate
# 2. H gate -> Z gate
# 3. Z gate -> H gate
# 4. H gate -> X gate
#
#
# </div>

# %% [markdown]
# <img src='data:image/png;base64,...'/>

# %%
answer4 = [2] # build your code here

# %% [markdown]
# <a id = "badge1_ex6"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 5: Which Qiskit code creates a quantum circuit called circ with 2 qubits and 2 classical bits?​ </b>
#
# 1. circ = QuantumCircuit(q = 2, c = 2)
# 2. QuantumCircuit(circ, 2, 2)
# 3. QuantumCircuit(name = circ, qubits = 2, bits =  2)
# 4. circ = QuantumCircuit(2,2)
#
#
# </div>

# %%
answer5 = [4] # build your code here

# %% [markdown]
# <a id = "badge1_ex7"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 6: Which circuit constructs the Bell state $|\phi^{+}\rangle = \frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$? </b>
#
# 1. Circuit A
# 2. Circuit B
# 3. Circuit C
# 4. Circuit D
#
#
# </div>

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %%
answer6 = [2] # build your code here

# %% [markdown]
# <a id = "badge1_ex8"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 7: Which circuit constructs the Bell state $|\Psi^{+}\rangle = \frac{1}{\sqrt{2}}(|01\rangle + |10\rangle)$? </b>
#
# 1. Circuit A
# 2. Circuit B
# 3. Circuit C
# 4. Circuit D
#
#
# </div>

# %% [markdown]
# <img src ='data:image/png;base64,...'>

# %%
answer7 = [4] # build your code here

# %% [markdown]
# <a id = "badge1_ex9"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 8: Which circuit constructs the GHZ-like state $|\Psi\rangle = \frac{1}{\sqrt{2}}(|010\rangle - |101\rangle)$ ? </b>
#
# 1. Circuit A
# 2. Circuit B
# 3. Circuit C
# 4. Circuit D
#
#
# </div>

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %%
answer8 = [2] # build your code here

# %% [markdown]
# <a id = "badge1_ex10"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 9: Alice's sending an unknown quantum state $|\psi\rangle$ (in purple) to Bob via quantum teleportation. She sends him two classical bits, $c_1c_0 = 10$, after performing her part of the algorithm. Which gate should Bob apply on his part of the Bell pair? </b>
#
# 1. Nothing
# 2. X Gate
# 3. Z Gate
# 4. ZX Gate
#
#
# </div>

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %%
answer9 = [2] # build your code here

# %% [markdown]
# <a id = "badge1_ex11"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 10: Which of the four states describes the state of the [doorbells in Whiskerton?](https://quantum-kittens.github.io/) </b>
#
#
# 1. $\frac{1}{\sqrt{2}}(|00\rangle + |11\rangle)$
# 2. $\frac{1}{\sqrt{2}}(|01\rangle + |10\rangle)$
# 3. $\frac{1}{\sqrt{2}}(|00\rangle + |01\rangle)$
# 4. $\frac{1}{\sqrt{2}}(|000\rangle + |111\rangle)$
#
#
# </div>

# %%
answer10 = [1] # build your code here

# %% [markdown]
# <a id = "badge1_ex12"></a>
#
# <div class="alert alert-block alert-info">
#
# <b> Question 11: What would be the measurement results for a $|+\rangle$ state?  </b>
#
#
# 1. Random for both z and x measurements.
# 2. Random for a z measurement, 0 for an x measurement.
# 3. Random for a z measurement, 1 for an x measurement.
# 4. 0 for a z measurement, 1 for an x measurement.
#
#
# </div>

# %%
answer11 = [3] # build your code here

# %% [markdown]
# ### Qiskit Code Question

# %% [markdown]
# <a id = "badge1_code"></a>
#
# <div class="alert alert-block alert-success">
#
# <b> Coding Question: Build a circuit with 4 qubits for the Qiskit logo state shown by the following Qsphere:</b>
# </div>

# %% [markdown]
# <img src ='data:image/png;base64,...'>

# %% [markdown]
# <details><summary><b>**Click to expand for hints.**</b></summary>
# <p>
#
#
# - Refer to the **[Qiskit documentation on the Qsphere](https://qiskit.org/documentation/stubs/qiskit.visualization.plot_state_qsphere.html)**
# - Tweak the circuit until the Qsphere corresponding to your circuit matches the given Qsphere.
#
# </p>
# </details>

# %%
from qiskit import QuantumCircuit
from qiskit.visualization import plot_state_qsphere

####### build your code below #########
circuit = QuantumCircuit(4)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(0, 2)
circuit.cx(0, 3)
circuit.x(1)

####### build your code above #########

display(plot_state_qsphere(circuit))
display(circuit.draw('mpl'))

answer12 = circuit

# %% [markdown]
# ### Extra Credit Multiple Choice Questions
#
# These questions are more advanced.

# %% [markdown]
# <a id = "badge1_ex13"></a>
#
# <div class="alert alert-block alert-warning">
#
# <b> <u>Extra Credit Question A</u>: Which circuit constructs the controlled-Y gate?  </b>
#
#
# 1. Circuit A
# 2. Circuit B
# 3. Circuit C
# 4. Circuit D
#
# </div>

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %%
answer13 = [3] # build your code here

# %% [markdown]
# <a id = "badge1_ex14"></a>
#
# <div class="alert alert-block alert-warning">
#
# <b> <u>Extra Credit Question B</u>: Which quantum circuit finds 01 among 00, 01, 10, 11 in Grover's algorithm? The bit ordering is q1q0. </b>
#
#
# 1. Circuit A
# 2. Circuit B
# 3. Circuit C
# 4. Circuit D
#
# </div>

# %% [markdown]
# <img src = 'data:image/png;base64,...'>

# %%
answer14 = [2] # build your code here

# %% [markdown]
# <a id = "badge1_ex15"></a>
#
# <div class="alert alert-block alert-warning">
#
# <b> <u>Extra Credit Question C</u>: Find the number of iterations with the largest amplitude when you run Grover's algorithm with one solution in a database with $N = 2^6$. Hint: Fewer than 12 times. </b>
#
#
# 1. 5
# 2. 6
# 3. 7
# 4. 8
#
# </div>

# %%
answer15 = [2] # build your code here

# %% [markdown]
# ## 점수 확인

# %%
answer = [answer1,answer2,answer3,answer4,answer5,answer6,answer7,answer8,answer9,answer10,answer11,answer13,answer14,answer15,answer12]

# %%
# Run this cell to check whether you've passed.

from qff_ku_grader.challenges.qff_ku2023 import grade_challenge2

grade_challenge2(answer)
# Out:
# Your Challenge2 score is 19

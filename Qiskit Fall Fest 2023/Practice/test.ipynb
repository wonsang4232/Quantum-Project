# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

# Use Aer's AerSimulator
simulator = AerSimulator()

# Create a Quantum Circuit acting on the q register
circuit = QuantumCircuit(2, 2)

# Add a H gate on qubit 0
circuit.h(0)

# Add a CX (CNOT) gate on control qubit 0 and target qubit 1
circuit.cx(0, 1)

# Map the quantum measurement to the classical bits
circuit.measure([0, 1], [0, 1])

# Compile the circuit for the support instruction set (basis_gates)
# and topology (coupling_map) of the backend
compiled_circuit = transpile(circuit, simulator)

# Execute the circuit on the aer simulator
job = simulator.run(compiled_circuit, shots=10000)

# Grab results from the job
result = job.result()

# Returns counts
counts = result.get_counts(compiled_circuit)
print("\nTotal count for 00 and 11 are:", counts)

# Draw the circuit
circuit.draw(output='mpl',style="iqp")
# Out:
# Total count for 00 and 11 are: {'00': 5001, '11': 4999}

# %%
plot_histogram(counts)

# %%
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram

simulator = AerSimulator()

circuit = QuantumCircuit(2, 2)

# step 1
circuit.h(0)
circuit.cx(0, 1)

# step 2
#circuit.x(0)
circuit.z(0)

# step 3
circuit.cx(0, 1)
circuit.h(0)

circuit.measure([0, 1], [0, 1])

compiled_circuit = transpile(circuit, simulator)

job = simulator.run(compiled_circuit, shots=10000)

# Grab results from the job
result = job.result()
statevector = result.get_statevector()
print(statevector)

print(result.get_counts(compiled_circuit))

circuit.draw(output = 'mpl',style = "iqp")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/qiskit/result/result.py:314, in Result.get_statevector(self, experiment, decimals)
#     312 try:
#     313     return postprocess.format_statevector(
# --> 314         self.data(experiment)["statevector"], decimals=decimals
#     315     )
#     316 except KeyError as ex:
#
# KeyError: 'statevector'
#
# The above exception was the direct cause of the following exception:
#
# QiskitError                               Traceback (most recent call last)
# Cell In[2], line 29
#      27 # Grab results from the job
#      28 result = job.result()
# ---> 29 statevector = result.get_statevector()
#      30 print(statevector)
#      32 print(result.get_counts(compiled_circuit))
#
# File /opt/homebrew/lib/python3.11/site-packages/qiskit/result/result.py:317, in Result.get_statevector(self, experiment, decimals)
#     313     return postprocess.format_statevector(
#     314         self.data(experiment)["statevector"], decimals=decimals
#     315     )
#     316 except KeyError as ex:
# --> 317     raise QiskitError(f'No statevector for experiment "{repr(experiment)}"') from ex
#
# QiskitError: 'No statevector for experiment "None"'
